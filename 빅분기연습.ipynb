# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1유형

# %%
df = pd.read_csv('C:/Users/yeons/OneDrive/바탕 화면/yemoonsaBigdata-main/yemoonsaBigdata-main/datasets/Part2/iris.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
a = df.groupby(['species'])['petal_length'].quantile(0.75)
a
# Out:
# species
# setosa        1.575
# versicolor    4.600
# virginica     5.875
# Name: petal_length, dtype: float64

# %%
# 중복 제거

a = df['sepal_length'].unique().tolist()

a.sort()

a[9]
# Out:
# 5.2

# %%
a = df.sort_values(by='sepal_width', ascending = False)

a = a.head(100)

std = a['sepal_width'].std()

std
# Out:
# 0.32682123739457536

# %%
# 이상치 / 평균 +- 2 표준편차


a = df['sepal_length'].mean() + 2 * df['sepal_length'].std()


b = df['sepal_length'].mean() - 2 * df['sepal_length'].std()

result1 = df['sepal_length'] >= a

result2 = df['sepal_length'] <= b

result = df[result1 | result2] # | 합집합 , & 교집합
result
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 105           7.6          3.0           6.6          2.1  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# 135           7.7          3.0           6.1          2.3  virginica

# %%
df = pd.read_csv('C:/Users/yeons/OneDrive/바탕 화면/yemoonsaBigdata-main/yemoonsaBigdata-main/datasets/Part2/wine.csv')
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0            NaN
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37                NaN      120.0            NaN
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
df = pd.read_csv('C:/Users/yeons/OneDrive/바탕 화면/yemoonsaBigdata-main/yemoonsaBigdata-main/datasets/Part2/wine.csv')
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0            NaN
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37                NaN      120.0            NaN
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
a = df.dropna(subset = ['total_phenols'])

b = a.fillna(a['alcalinity_of_ash'].median())

b
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# 5      14.20        1.76  2.45               15.2      112.0           3.27
# ..       ...         ...   ...                ...        ...            ...
# 172    14.16        2.51  2.48               20.0       91.0           1.68
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
# alcohol 값이 alcohol 평균 값 이상이고, color_intensity 값이 colot_intensity 평균 값 이상인 데이터만 남겼을 때, 가장 많은 class 값을 구하시오

a = (df['alcohol'] >= df['alcohol'].mean())

b = (df['color_intensity'] >= df['color_intensity'].mean())

result = df[a&b]

len(result[result['class']==0]),len(result[result['class']==1]), len(result[result['class']==2])
# Out:
# (37, 1, 23)

# %%
# class 1에 해당하는 데이터의 ash 평균값과 모든 결측치를 제거한 후 ash 값의 평균값의 차이의 절댓값을 계산


a = df[df['class']==1]['ash'].mean()

b = df['ash'].dropna().mean()

result = abs(b-a)
result
# Out:
# 0.12172812153822044

# %%
# alcohol 변수의 상위 20번째 값으로 상위 20개의 값을 변환한 후, proanthocyanins가 2이하인 데이터를 추출하여 alcohol의 평균값을 계산

a = df.sort_values(['alcohol'], ascending = False).reset_index()

a20 = a.loc[19, 'alcohol']

a.loc[0:19, 'alcohol'] = a20

result = a[a['proanthocyanins']<=2]['alcohol'].mean()
result
# Out:
# 12.923986013986003

# %%
# class 1에 해당하는 데이터의 proline 변수의 제 3사분위수 제 1사분위수 차를 구하고, class 2에 해당하는 데이터의 proline 변수의 제 3분위


a = df[df['class']==1]['proline'].quantile(0.75)

b = df[df['class']==1]['proline'].quantile(0.25)

dif1 = a-b

c = df[df['class']==2]['proline'].quantile(0.75)

d = df[df['class']==2]['proline'].quantile(0.25)

dif2 = c-d

result = abs(dif1-dif2)
result
# Out:
# 68.5

# %%
import seaborn as sns
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# total_bill 변수의 제 1사분위수를 구하고 정수값으로 출력

int(df['total_bill'].quantile(0.25))
# Out:
# 13

# %%
# total_bill 값이 20이상 25이하인 데이터의 수를 구하시오

a = df['total_bill'] >= 20
b = 25 >= df['total_bill']

result = df[a&b]
len(result)
# Out:
# 42

# %%
# tip 변수의 IQR 값을 구하시오  Q3 - Q1

iqr = df['tip'].quantile(0.75) - df['tip'].quantile(0.25)

iqr
# Out:
# 1.5625

# %%
# TIP 변수의 상위 10개의 총합을 구하여 소수점을 버리고 정수로 출력하시오

a = df.sort_values(['tip'], ascending = False)

b = a.head(10)

int(b['tip'].sum())
# Out:
# 70

# %%
# 전체 데이터에서 sex가 Female인 비율이 얼마

a = len(df[df['sex']=='Female']) / len(df)

result = a * 100
result
# Out:
# 35.65573770491803

# %%
# 첫번째 행부터 순서대로 10개 뽑은 후 total_bill 열의 평균값을 반올림하여 정수로 출력

b = df.head(10)

int(round(b['total_bill'].mean()))
# Out:
# 19

# %%
# 첫번쨰 행부터 순서대로 50%까지 데이터를 뽑아 tip 변수의 중앙값을 구하시오.

a = df[:122]

b = a['tip'].median()
b
# Out:
# 3.0

# %%
df = sns.load_dataset('mpg')
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
# 결측치 값이 있는 데이터의 수를 구하싱오

df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
# horsepower 결측값을 horespower 평균값으로 대체, horsepower의 중앙값을 정수로 출력

df['horsepower'] = df['horsepower'].fillna(df['horsepower'].mean())

df['horsepower'].median()
# Out:
# 95.0

# %%
# hourespower 컬럼에 결측치가 있는 행을 제거하고, 첫번째 행부터 순서대로 50%를 추출한 후 해당 데이터의 1사분위수를 구하시오

a = df['horsepower'].dropna()

a.head(196).quantile(0.25)
# Out:
# 86.75

# %%
# clyinder가 3인 자동차와 8인 자동차 그룹의 mpg 평균값 차이를 절대값 정수로 출력

a = df[df['cylinders'] == 3]['mpg'].mean()
b = df[df['cylinders'] == 8]['mpg'].mean()

abs(b-a)
# Out:
# 5.586893203883493

# %%
# horespower 변수를 z-score 표준화를 진행하고 이상치 수를 구하시오. z 1.5 초과, -1.5 미만
# z-score -> z = (x-평균) / 표준편차

mean = df['horsepower'].mean()

std =  df['horsepower'].std()

z_score = (df['horsepower']- mean) / std

a = z_score > 1.5

b = z_score < -1.5

result = z_score[a|b]

len(result)
# Out:
# 39

# %%
# mpg 컬럼을 min-max 정규화를 진행한 후 0.8보다 큰 값을 가지는 레코드 수를 구하시오.

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df['mpg'] = scaler.fit_transform(df[['mpg']])

a = df['mpg'][df['mpg'] > 0.8]
len(a)
# Out:
# 11

# %%
# weight 컬럼에 대해 상자그림 기준으로 이상치의 갯수를 구하시오.
# iqr 사용 -> Q3 + 1.5 * IQR / Q1 = 1.5 * IQR

q3 = df['weight'].quantile(0.75)

q1 = df['weight'].quantile(0.25)

iqr = q3 - q1

a = q3 + 1.5* iqr

b = q1 - 1.5*iqr

result1 = df['weight'] > a
result2 = df['weight'] < b

result = df[result1|result2]
result
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, model_year, origin, name]
# Index: []

# %%
df = sns.load_dataset('mpg')
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
# model_year가 80보다 큰 차량 중에 mpg 값이 가장 큰 차량의 hourespower값을 합산하여 출력하시오.

a = df[df['model_year'] > 80]['mpg'].max()

result = df[df['mpg'] == a]['horsepower'].sum()
result
# Out:
# 52.0

# %%
# origin이 usa, europe인 데이터 hourespower 표준편차값의 차이를 절대값으로 소수 첫째 자리까지 출력

usa = df[df['origin'] == 'usa']
eur = df[df['origin'] == 'europe']

abs(usa.std() - eur.std())
# Out:
# C:\Users\yeons\AppData\Local\Temp\ipykernel_20336\901235934.py:6: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   abs(usa.std() - eur.std())
# mpg               0.321038
# cylinders         1.161114
# displacement     75.919759
# horsepower       19.739919
# weight          304.749316
# acceleration      0.294575
# model_year        0.207588
# dtype: float64

# %%
# origin 별로 그룹화하여 weight 평균값을 산출하고 평균값이 높은 그룹의 weight 3사분위수 값을 구하시오

df['origin'].value_counts()

usa = df[df['origin'] == 'usa'].mean()

jan = df[df['origin'] == 'japan'].mean()

eur = df[df['origin'] == 'europe'].mean()

df[df['origin'] == 'usa']['weight'].quantile(0.75)
# Out:
# C:\Users\yeons\AppData\Local\Temp\ipykernel_20336\4224022492.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   usa = df[df['origin'] == 'usa'].mean()
# C:\Users\yeons\AppData\Local\Temp\ipykernel_20336\4224022492.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   jan = df[df['origin'] == 'japan'].mean()
# C:\Users\yeons\AppData\Local\Temp\ipykernel_20336\4224022492.py:9: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   eur = df[df['origin'] == 'europe'].mean()
# 4054.0

# %%
# name 별로 그룹화하여 mpg 중앙값을 산출하고 중앙값이 높은 그룹의 mpg 1사분위수 값을 구하시오

a = df.groupby(['name'])['mpg'].median()
b = a.sort_values(ascending = False)
c = df[df['name']=='mazda glc']['mpg'].quantile(0.25)
c
# Out:
# 46.6

# %%
# horespower 상위 10번째 값으로 상위 10개 값을 변환한 후, horsepower가 150 이상인 데이터를 추출하여 horespower의 평균값을 반올림하여 정수

df = sns.load_dataset('mpg')

a = df.sort_values('horsepower',ascending=False, ignore_index=True)

b = a.head(10)

c = b[b['horsepower'] >= 150]

result = c['horsepower'].mean()
result
# Out:
# 218.8

# %%
# name 변수에 mercury 문구가 포함된 자동차의 mpg 평균값을 정수로 출력

a = df['name'].str.contains('mercury')

result = df[a]['mpg'].mean()

result
# Out:
# 19.11818181818182

# %%
# horsepower weight 상관계수 구하기

df['horsepower'].corr(df['weight'])
# Out:
# 0.864537737574144

# %%
# mpg와 상관관계가 높은 수치형 변수

df.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %%
import pandas as pd

df = pd.DataFrame({
    '날짜' : ['20220102', '20220103', '20220104', '20220515'],
    '제품' : ['사과','딸기','사과',None],
    '판매량' : [3,None, 5, 7],
    '개당수익' : [300,400,500,600]
})

df
# Out:
#          날짜    제품  판매량  개당수익
# 0  20220102    사과  3.0   300
# 1  20220103    딸기  NaN   400
# 2  20220104    사과  5.0   500
# 3  20220515  None  7.0   600

# %%
# 판매량 컬럼의 결측치를 최소값으로 대체하고 결측치가 있을 때와 최소값으로 대체했을 때 평균값의 차이를 절대값 정수로 출력
df1 = df
a = df['판매량'].min()
df1['판매량']= df1['판매량'].fillna(a)

(abs(df['판매량'].mean() - df1['판매량'].mean()))
# Out:
# 0.0

# %%
# 22년 1분기 사과 매출액을 구하시오 / 매출액 = 판매량 * 개당수익

df['판매량'].fillna(df['판매량'].min())

df['매출액'] = df['판매량'] * df['개당수익']

df['날짜'] = pd.to_datetime(df['날짜'])

df['년'] = df['날짜'].dt.year

df['분기'] = df['날짜'].dt.quarter

df['시']

a = df[df['분기'] ==  1]['매출액'].sum()
a
# Out:
# 4600.0

# %%
# 15시 ~ 23시 사이 전체 제품 판매량을 구하시오

time = pd.date_range('2023-07-24 12:00:00', '2023-07-25 14:50:30', periods=4)

df1['time'] = time

df1

cond = df1['time'].between('2023-07-24 15:00','2023-07-24 23:00')

result = df1[cond]['판매량'].sum()
result
# Out:
# 4.5

# %% [markdown]
# # 2유형

# %%
# 출력을 원하실 경우 print() 함수 활용
# 예시) print(df.head())

# getcwd(), chdir() 등 작업 폴더 설정 불필요
# 파일 경로 상 내부 드라이브 경로(C: 등) 접근 불가

import pandas as pd

train = pd.read_csv("data/customer_train.csv")
test = pd.read_csv("data/customer_test.csv")

y_train = train['성별']
train = train.drop(columns=['회원ID','성별'])
test = test.drop(columns=['회원ID'])

from sklearn.model_selection import train_test_split

x_train1, x_test1 , y_train1 , y_test1 = train_test_split(train, y_train)

# 결측치 처리
train['환불금액'] = train['환불금액'].fillna(train['환불금액'].mean())
test['환불금액'] = train['환불금액'].fillna(test['환불금액'].mean())


from sklearn.preprocessing import LabelEncoder, StandardScaler
# 문자형 데이터
encoder = LabelEncoder()

train['주구매상품'] = encoder.fit_transform(train['주구매상품'])
test['주구매상품'] = encoder.transform(test['주구매상품'])

train['주구매지점'] = encoder.fit_transform(train['주구매지점'])
test['주구매지점'] = encoder.transform(test['주구매지점'])

# 수치형 데이터
scaler = StandardScaler()

train['총구매액'] = scaler.fit_transform(train[['총구매액']])
test['총구매액'] = scaler.transform(test[['총구매액']])

train['최대구매액'] = scaler.fit_transform(train[['최대구매액']])
test['최대구매액'] = scaler.transform(test[['최대구매액']])

train['환불금액'] = scaler.fit_transform(train[['환불금액']])
test['환불금액'] = scaler.transform(test[['환불금액']])

train['방문일수'] = scaler.fit_transform(train[['방문일수']])
test['방문일수'] = scaler.transform(test[['방문일수']])

train['방문당구매건수'] = scaler.fit_transform(train[['방문당구매건수']])
test['방문당구매건수'] = scaler.transform(test[['방문당구매건수']])

train['주말방문비율'] = scaler.fit_transform(train[['주말방문비율']])
test['주말방문비율'] = scaler.transform(test[['주말방문비율']])

train['구매주기'] = scaler.fit_transform(train[['구매주기']])
test['구매주기'] = scaler.transform(test[['구매주기']])

# 모델 학습

from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, roc_auc_score

rm1 = RandomForestClassifier(n_estimators=100, max_depth = 5, min_samples_split = 5)
rm2 = RandomForestClassifier(n_estimators=100, max_depth = 5, min_samples_split = 10)
rm3 = RandomForestClassifier(n_estimators=100, max_depth = 10, min_samples_split = 10)

et1 = ExtraTreesClassifier(n_estimators=100, max_depth = 5, min_samples_split = 5)
et2 = ExtraTreesClassifier(n_estimators=100, max_depth = 5, min_samples_split = 10)
et3 = ExtraTreesClassifier(n_estimators=100, max_depth = 10, min_samples_split = 10)

gb1 = GradientBoostingClassifier(n_estimators=100, max_depth = 5, min_samples_split = 5)
gb2 = GradientBoostingClassifier(n_estimators=100, max_depth = 5, min_samples_split = 10)
gb3 = GradientBoostingClassifier(n_estimators=100, max_depth = 10, min_samples_split = 10)





# 최적 모델 선정 이후 / 제출 까지

rm1.fit(train, y_train)

pred = rm1.predict(test)

pd.DataFrame({"pred" : pred}).to_csv("result.csv", index=False)

result = pd.read_csv("result.csv")

print(result)



# pd.DataFrame변수.to_csv("result.csv", index=False)

# %% [markdown]
# # 3유형

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import scipy.stats as stats

# %%
df = pd.read_csv('C:/Users/yeons/OneDrive/바탕 화면/yemoonsaBigdata-main/yemoonsaBigdata-main/datasets/supplement/trees.csv')
df
# Out:
#     Girth  Height  Volume
# 0     8.3      70    10.3
# 1     8.6      65    10.3
# 2     8.8      63    10.2
# 3    10.5      72    16.4
# 4    10.7      81    18.8
# 5    10.8      83    19.7
# 6    11.0      66    15.6
# 7    11.0      75    18.2
# 8    11.1      80    22.6
# 9    11.2      75    19.9
# 10   11.3      79    24.2
# 11   11.4      76    21.0
# 12   11.4      76    21.4
# 13   11.7      69    21.3
# 14   12.0      75    19.1
# 15   12.9      74    22.2
# 16   12.9      85    33.8
# 17   13.3      86    27.4
# 18   13.7      71    25.7
# 19   13.8      64    24.9
# 20   14.0      78    34.5
# 21   14.2      80    31.7
# 22   14.5      74    36.3
# 23   16.0      72    38.3
# 24   16.3      77    42.6
# 25   17.3      81    55.4
# 26   17.5      82    55.7
# 27   17.9      80    58.3
# 28   18.0      80    51.5
# 29   18.0      80    51.0
# 30   20.6      87    77.0

# %%
# 단일표본 T 검정
stat , pval = stats.ttest_1samp(df['Height'],75)
stat, pval
# Out:
# (0.8738116490580545, 0.38916223357338076)

# %%
result = []

if pval < 0.05 :
    result = '기각'
    
else :
    result = '채택'
    
result
# Out:
# '채택'

# %%
df = pd.read_csv('C:/Users/yeons/OneDrive/바탕 화면/yemoonsaBigdata-main/yemoonsaBigdata-main/datasets/supplement/toothgrowth.csv')
df
# Out:
#      len supp  dose
# 0    4.2   VC   0.5
# 1   11.5   VC   0.5
# 2    7.3   VC   0.5
# 3    5.8   VC   0.5
# 4    6.4   VC   0.5
# 5   10.0   VC   0.5
# 6   11.2   VC   0.5
# 7   11.2   VC   0.5
# 8    5.2   VC   0.5
# 9    7.0   VC   0.5
# 10  16.5   VC   1.0
# 11  16.5   VC   1.0
# 12  15.2   VC   1.0
# 13  17.3   VC   1.0
# 14  22.5   VC   1.0
# 15  17.3   VC   1.0
# 16  13.6   VC   1.0
# 17  14.5   VC   1.0
# 18  18.8   VC   1.0
# 19  15.5   VC   1.0
# 20  23.6   VC   2.0
# 21  18.5   VC   2.0
# 22  33.9   VC   2.0
# 23  25.5   VC   2.0
# 24  26.4   VC   2.0
# 25  32.5   VC   2.0
# 26  26.7   VC   2.0
# 27  21.5   VC   2.0
# 28  23.3   VC   2.0
# 29  29.5   VC   2.0
# 30  15.2   OJ   0.5
# 31  21.5   OJ   0.5
# 32  17.6   OJ   0.5
# 33   9.7   OJ   0.5
# 34  14.5   OJ   0.5
# 35  10.0   OJ   0.5
# 36   8.2   OJ   0.5
# 37   9.4   OJ   0.5
# 38  16.5   OJ   0.5
# 39   9.7   OJ   0.5
# 40  19.7   OJ   1.0
# 41  23.3   OJ   1.0
# 42  23.6   OJ   1.0
# 43  26.4   OJ   1.0
# ...

# %%
vc_len = df[df['supp']=='VC']['len']
oj_len = df[df['supp']=='OJ']['len']

# %%
# 독립 표본 T- 검정 
stat, pval = stats.ttest_ind(vc_len, oj_len)
stat, pval
# Out:
# (-1.91526826869527, 0.06039337122412849)

# %%
df = pd.read_csv('C:/Users/yeons/OneDrive/바탕 화면/yemoonsaBigdata-main/yemoonsaBigdata-main/datasets/supplement/Insectsprays.csv')
df
# Out:
#     before_spr  after_spr
# 0           10          0
# 1            7          1
# 2           20          7
# 3           14          2
# 4           14          3
# 5           12          1
# 6           10          2
# 7           23          1
# 8           17          3
# 9           20          0
# 10          14          1
# 11          13          4
# 12          11          3
# 13          17          5
# 14          21         12
# 15          11          6
# 16          16          4
# 17          14          3
# 18          17          5
# 19          17          5
# 20          19          5
# 21          21          5
# 22           7          2
# 23          13          4
# 24          11          3
# 25           9          5
# 26          15          3
# 27          22          5
# 28          15          3
# 29          16          6
# 30          13          1
# 31          10          1
# 32          26          3
# 33          26          2
# ...

# %%
# 쌍체포본 T-검정 실습

stat, pval = stats.ttest_rel(df['before_spr'],df['after_spr'], alternative = 'greater')

# alternative (two.side: 양측 검정 같다 같지 않다) 
#(less) : 왼쪽 <두번째 집단이 크다>
# (greater) : 오른쪽 <첫번째 집단이 크다>

stat, pval
# Out:
# (14.893263274163433, 5.113978478699233e-17)

# %%
df = pd.read_csv('C:/Users/yeons/OneDrive/바탕 화면/yemoonsaBigdata-main/yemoonsaBigdata-main/datasets/supplement/iris.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# 일원 분산 분석


x1 = df.loc[df['species']=='setosa', 'sepal_length']
x2 = df.loc[df['species']=='versicolor', 'sepal_length']
x3 = df.loc[df['species']=='virginica', 'sepal_length']


stat, pval = stats.f_oneway(x1,x2,x3)
stat, pval
# Out:
# (119.26450218450468, 1.6696691907693826e-31)

# %%
df = pd.read_csv('C:/Users/yeons/OneDrive/바탕 화면/yemoonsaBigdata-main/yemoonsaBigdata-main/datasets/supplement/cellphone.csv')
df
# Out:
#       id 제조사
# 0      1  삼성
# 1      2  애플
# 2      3  삼성
# 3      4  애플
# 4      5  애플
# ..   ...  ..
# 195  196  삼성
# 196  197  삼성
# 197  198  삼성
# 198  199  애플
# 199  200  애플
#
# [200 rows x 2 columns]

# %%
count = df.groupby('제조사').count()
count
# Out:
#       id
# 제조사
# 기타     5
# 삼성   117
# 애플    78

# %%
# 카이스퀘어로 적합성 검정

total_sum = len(df)

expect = [int(total_sum * 0.1),int(total_sum * 0.6), int(total_sum * 0.3)]

observed = count['id'].values

stat, pval = stats.chisquare(observed, f_exp=expect)

stat, pval
# Out:
# (16.725, 0.00023345995371416804)

# %%
df = pd.read_csv('C:/Users/yeons/OneDrive/바탕 화면/yemoonsaBigdata-main/yemoonsaBigdata-main/datasets/supplement/student.csv')
df
# Out:
#       ID  단과대학 수강 과목 수
# 0      1  경영대학   4개 이하
# 1      2  경영대학   4개 이하
# 2      3  경영대학   4개 이하
# 3      4  경영대학   4개 이하
# 4      5  경영대학   4개 이하
# ..   ...   ...     ...
# 295  296  공과대학   6개 이상
# 296  297  공과대학   6개 이상
# 297  298  공과대학   6개 이상
# 298  299  공과대학   6개 이상
# 299  300  공과대학   6개 이상
#
# [300 rows x 3 columns]

# %%
table = pd.crosstab(df['단과대학'], df['수강 과목 수'])
table
# Out:
# 수강 과목 수  4개 이하  5개  6개 이상
# 단과대학
# 경영대학        12  78     30
# 공과대학        30  42     28
# 자연대학        30  42      8

# %%
x1 = table.loc['경영대학', :]

x2 = table.loc['공과대학', :]

x3 = table.loc['자연대학', :]

stat, pval , _ , _ = stats.chi2_contingency([x1,x2,x3])
stat, pval
# Out:
# (30.127525252525256, 4.6103966676496775e-06)

# %%
import statsmodels.api as sm

# %%
# 조정된 데이터 생성: 온도와 아이스크림 매출
np.random.seed(0)  # 결과의 일관성을 위해 시드 재설정
temperatures = np.random.randint(20, 35, 100)  # 더 많은 데이터 포인트 추가
sales = temperatures * 70 - 500 + np.random.normal(0, 100, 100)  # 기울기와 절편 조정, 변동성 조정

# DataFrame 생성
data = pd.DataFrame({
    'Temperature': temperatures,
    'Ice_Cream_Sales': sales
})

# %%
# 단순선형회귀

X = sm.add_constant(data['Temperature'])

y = data['Ice_Cream_Sales']

model = sm.OLS(y,X).fit()

summary = model.summary()

summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Ice_Cream_Sales   R-squared:                       0.874
# Model:                            OLS   Adj. R-squared:                  0.873
# Method:                 Least Squares   F-statistic:                     680.3
# Date:                Fri, 21 Jun 2024   Prob (F-statistic):           6.90e-46
# Time:                        17:02:43   Log-Likelihood:                -606.75
# No. Observations:                 100   AIC:                             1217.
# Df Residuals:                      98   BIC:                             1223.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        -452.2143     68.982     -6.556      0.000    -589.106    -315.322
# ...

# %%
# 변수 조정: 독립 변수 중 하나의 영향을 줄이고, 절편의 통계적 유의성을 높이기 위해 데이터 조정
np.random.seed(0)  # 결과의 일관성을 위해 시드 재설정
fish_length_adj = np.random.uniform(15, 40, 100)  # 길이: 조정 없음
fish_width_adj = np.random.uniform(5, 10, 100)  # 폭: 조정 없음
fish_thickness_adj = np.random.uniform(1, 5, 100) * 0.1  # 두께: 영향을 줄임
fish_fin_length_adj = np.random.uniform(3, 8, 100)  # 지느러미 길이: 조정 없음

# 무게 계산식 조정: 절편의 유의성을 높이기 위해 기본 무게를 추가
fish_weight_adj = 200 + 20 * fish_length_adj + 10 * fish_width_adj + 5 * fish_thickness_adj + 15 * fish_fin_length_adj + np.random.normal(0, 10, 100)

# 조정된 DataFrame 생성
data = pd.DataFrame({
    'Length': fish_length_adj,
    'Width': fish_width_adj,
    'Thickness': fish_thickness_adj,
    'Fin_Length': fish_fin_length_adj,
    'Weight': fish_weight_adj
})

# %%
# 다중회귀 분석

import statsmodels.api as sm

X = sm.add_constant(data[['Length', 'Width', 'Thickness', 'Fin_Length']])
y = data['Weight']

model = sm.OLS(y,X).fit()

summary = model.summary()

summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Weight   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                     6376.
# Date:                Fri, 21 Jun 2024   Prob (F-statistic):          1.72e-114
# Time:                        17:02:57   Log-Likelihood:                -361.50
# No. Observations:                 100   AIC:                             733.0
# Df Residuals:                      95   BIC:                             746.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        191.6867      8.260     23.207      0.000     175.289     208.084
# ...

# %%
# 데이터 생성
np.random.seed(0)
house_size = np.random.uniform(50, 250, 100)  # 주택 크기: 50제곱미터에서 250제곱미터
house_price = 5000 + 20 * house_size + 0.2 * house_size**2 + np.random.normal(0, 2000, 100)  # 주택 가격: 강한 비선형 관계

# DataFrame 생성
house_data = pd.DataFrame({
    'Size': house_size,
    'Price': house_price
})

# 다항 특성 생성: Size^2
house_data['Size^2'] = house_data['Size']**2

# %%
# 다항선형회귀분석

X = sm.add_constant(house_data[['Size', 'Size^2']])

y = house_data['Price']

model = sm.OLS(y,X).fit()

summary = model.summary()

summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.839
# Model:                            OLS   Adj. R-squared:                  0.836
# Method:                 Least Squares   F-statistic:                     253.2
# Date:                Fri, 21 Jun 2024   Prob (F-statistic):           3.15e-39
# Time:                        17:04:21   Log-Likelihood:                -900.64
# No. Observations:                 100   AIC:                             1807.
# Df Residuals:                      97   BIC:                             1815.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3835.8351   1312.331      2.923      0.004    1231.222    6440.449
# ...

# %%
from sklearn.datasets import load_iris


# iris 데이터셋 로드
iris = load_iris()
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)

# versicolor(1)와 virginica(2)만 선택하고, 종(species)을 이진 변수로 변환: versicolor=0, virginica=1
iris_df['species'] = iris.target
iris_filtered = iris_df[(iris_df['species'] == 1) | (iris_df['species'] == 2)]
iris_filtered['species'] = iris_filtered['species'].map({1: 0, 2: 1})

# 독립 변수와 종속 변수 설정
X = iris_filtered.drop('species', axis=1)
y = iris_filtered['species']
# Out:
# C:\Users\yeons\AppData\Local\Temp\ipykernel_20336\3113854390.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iris_filtered['species'] = iris_filtered['species'].map({1: 0, 2: 1})

# %%
# 로지스틱회귀분석

X = sm.add_constant(X)

y 

model = sm.Logit(y,X).fit()

summary = model.summary()

summary
# Out:
# Optimization terminated successfully.
#          Current function value: 0.059493
#          Iterations 12
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                species   No. Observations:                  100
# Model:                          Logit   Df Residuals:                       95
# Method:                           MLE   Df Model:                            4
# Date:                Fri, 21 Jun 2024   Pseudo R-squ.:                  0.9142
# Time:                        17:05:56   Log-Likelihood:                -5.9493
# converged:                       True   LL-Null:                       -69.315
# Covariance Type:            nonrobust   LLR p-value:                 1.947e-26
# ...
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...
